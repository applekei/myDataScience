# %%
import pandas

# %%
rain_table = pandas.read_csv('IDCJAC0009_066062_2016_Data.csv');

# %%
rain_table
# Out:
#     Product code  Bureau of Meteorology station number  Year  Month  Day  \
# 0     IDCJAC0009                                 66062  2016      1    1
# 1     IDCJAC0009                                 66062  2016      1    2
# 2     IDCJAC0009                                 66062  2016      1    3
# 3     IDCJAC0009                                 66062  2016      1    4
# 4     IDCJAC0009                                 66062  2016      1    5
# 5     IDCJAC0009                                 66062  2016      1    6
# 6     IDCJAC0009                                 66062  2016      1    7
# 7     IDCJAC0009                                 66062  2016      1    8
# 8     IDCJAC0009                                 66062  2016      1    9
# 9     IDCJAC0009                                 66062  2016      1   10
# 10    IDCJAC0009                                 66062  2016      1   11
# 11    IDCJAC0009                                 66062  2016      1   12
# ...

# %%
RainFallSum = rain_table[]
